# %%
import pandas as pd

# %%
#iloc = uses observations’ position.
fund = pd.read_csv('startup_funding.csv')
fund.head()
# Out:
#    SNo        Date   StartupName   IndustryVertical  \
# 0    0  01/08/2017      TouchKin         Technology
# 1    1  02/08/2017       Ethinos         Technology
# 2    2  02/08/2017  Leverage Edu  Consumer Internet
# 3    3  02/08/2017          Zepo  Consumer Internet
# 4    4  02/08/2017  Click2Clinic  Consumer Internet
#
#                                      SubVertical CityLocation  \
# 0                       Predictive Care Platform    Bangalore
# 1                       Digital Marketing Agency       Mumbai
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
#
#                                        InvestorsName  InvestmentType  \
# 0                                        Kae Capital  Private Equity
# 1                         Triton Investment Advisors  Private Equity
# ...

# %%
fund.shape
# Out:
# (2372, 10)

# %%
fund.iloc[[3]]  # accesing of particular row
# Out:
#    SNo        Date StartupName   IndustryVertical             SubVertical  \
# 3    3  02/08/2017        Zepo  Consumer Internet  DIY Ecommerce platform
#
#   CityLocation                                      InvestorsName  \
# 3       Mumbai  Kunal Shah, LetsVenture, Anupam Mittal, Hetal ...
#
#   InvestmentType AmountInUSD Remarks
# 3   Seed Funding     500,000     NaN

# %%
fund.iloc[[-1]] # print the last row of data set
# Out:
#        SNo        Date       StartupName IndustryVertical SubVertical  \
# 2371  2371  31/01/2015  couponmachine.in              NaN         NaN
#
#      CityLocation                      InvestorsName InvestmentType  \
# 2371          NaN  UK based Group of Angel Investors   Seed Funding
#
#      AmountInUSD Remarks
# 2371     140,000     NaN

# %%
fund.iloc[[0,-1]] # print the  first and last row of dataset
# Out:
#        SNo        Date       StartupName IndustryVertical  \
# 0        0  01/08/2017          TouchKin       Technology
# 2371  2371  31/01/2015  couponmachine.in              NaN
#
#                    SubVertical CityLocation  \
# 0     Predictive Care Platform    Bangalore
# 2371                       NaN          NaN
#
#                           InvestorsName  InvestmentType AmountInUSD Remarks
# 0                           Kae Capital  Private Equity   1,300,000     NaN
# 2371  UK based Group of Angel Investors    Seed Funding     140,000     NaN

# %%
fund.iloc[[0,4,7,8,9,10,-1],[0,1,3,4]] # print the desired rows and columns
# Out:
#        SNo        Date   IndustryVertical  \
# 0        0  01/08/2017         Technology
# 4        4  02/08/2017  Consumer Internet
# 7        7  04/07/2017          eCommerce
# 8        8  05/07/2017          eCommerce
# 9        9  05/07/2017          eCommerce
# 10      10  05/07/2017  Consumer Internet
# 2371  2371  31/01/2015                NaN
#
#                                   SubVertical
# 0                    Predictive Care Platform
# 4               healthcare service aggregator
# 7          Online marketplace for automobiles
# 8     online marketplace for food and grocery
# 9     B2B marketplace for Industrial products
# 10          Hyperlocal home services provider
# 2371                                      NaN

# %%
fund.iloc[2:9,1:6] # print the rows from2 to 9-1 and columns 1 to 6-1
# Out:
#          Date       StartupName   IndustryVertical  \
# 2  02/08/2017      Leverage Edu  Consumer Internet
# 3  02/08/2017              Zepo  Consumer Internet
# 4  02/08/2017      Click2Clinic  Consumer Internet
# 5  01/07/2017     Billion Loans  Consumer Internet
# 6  03/07/2017  Ecolibriumenergy         Technology
# 7  04/07/2017             Droom          eCommerce
# 8  05/07/2017         Jumbotail          eCommerce
#
#                                      SubVertical CityLocation
# 2  Online platform for Higher Education Services    New Delhi
# 3                         DIY Ecommerce platform       Mumbai
# 4                  healthcare service aggregator    Hyderabad
# 5                  Peer to Peer Lending platform    Bangalore
# 6           Energy management solutions provider    Ahmedabad
# 7             Online marketplace for automobiles      Gurgaon
# 8        online marketplace for food and grocery    Bangalore

# %%
fund.iloc[:5,:3] # print row from 0 to 5-1 and columns 0 to 3-1
# Out:
#    SNo        Date   StartupName
# 0    0  01/08/2017      TouchKin
# 1    1  02/08/2017       Ethinos
# 2    2  02/08/2017  Leverage Edu
# 3    3  02/08/2017          Zepo
# 4    4  02/08/2017  Click2Clinic

# %%
fund.iloc[2365:,:] # print the from 2365 to onwards and all the columns
# Out:
#        SNo        Date       StartupName IndustryVertical SubVertical  \
# 2365  2365  27/01/2015      CarDekho.com              NaN         NaN
# 2366  2366  28/01/2015     Grabhouse.com              NaN         NaN
# 2367  2367  29/01/2015        Printvenue              NaN         NaN
# 2368  2368  29/01/2015          Graphene              NaN         NaN
# 2369  2369  30/01/2015    Mad Street Den              NaN         NaN
# 2370  2370  30/01/2015         Simplotel              NaN         NaN
# 2371  2371  31/01/2015  couponmachine.in              NaN         NaN
#
#      CityLocation                        InvestorsName  InvestmentType  \
# 2365          NaN  Hillhouse Capital, Tybourne Capital  Private Equity
# 2366          NaN     Kalaari Capital, Sequoia Capital  Private Equity
# 2367          NaN          Asia Pacific Internet Group  Private Equity
# 2368          NaN                       KARSEMVEN Fund  Private Equity
# ...

# %%
fund.set_index('StartupName',inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'StartupName'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-1d66127c7cab> in <module>()
# ...

# %%
fund.head()
# Out:
#            Date   IndustryVertical  \
# SNo
# 0    01/08/2017         Technology
# 1    02/08/2017         Technology
# 2    02/08/2017  Consumer Internet
# 3    02/08/2017  Consumer Internet
# 4    02/08/2017  Consumer Internet
#
#                                        SubVertical CityLocation  \
# SNo
# 0                         Predictive Care Platform    Bangalore
# 1                         Digital Marketing Agency       Mumbai
# 2    Online platform for Higher Education Services    New Delhi
# 3                           DIY Ecommerce platform       Mumbai
# 4                    healthcare service aggregator    Hyderabad
#
#                                          InvestorsName  InvestmentType  \
# SNo
# 0                                          Kae Capital  Private Equity
# 1                           Triton Investment Advisors  Private Equity
# 2    Kashyap Deorah, Anand Sankeshwar, Deepak Jain,...    Seed Funding
# ...
